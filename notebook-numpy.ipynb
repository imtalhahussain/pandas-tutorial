# %%
import numpy as np

# %%
#Python list
python_list = [1, 2, 3, 4, 5]

#Numpy Array
numpy_array = np.array([1, 2, 3, 4, 5])

print("Pyton List", python_list)
print("Numpy Array", numpy_array)

print ("\nType of Python List: ", type[int](python_list))
print("Type of Nummpy Array:", type[_AnyShape, dtype[Any]](numpy_array))

# KeY advantage : Vectorized operations (no loops needed)
# Adding 10 to each element
